# %%
import numpy as np 
import matplotlib.pyplot as plt
import PySO
from tk import *
import matplotlib
import os

# %%
global w
global r_star 

w = 1
r_star = 4

# %%
def test_func(x):
    """
    x: ndarray shape (Ndim)
        points at which to evaluate the function on 
    """
    r = np.linalg.norm(x) 
    
    # f = np.exp(-1/2*((r-r_star)/w)**2)+np.exp(-1/2*np.sum((x-r_star)**2))
    f = np.exp(-1/2*((r-r_star)/w)**2)*x[0]

    return(f)

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
X,Y = np.meshgrid(x,y)
input_array = np.array([X.flatten(),Y.flatten()]).T
res = []
for i in input_array:
    res.append(test_func(i))

# %%
# %matplotlib inline
res = np.array(res).reshape((1000,1000))

fig = plt.figure(figsize=(20,20))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, res, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %%
# Number of dimensions used for PySO problem

# %%
#Simple gaussian to optimize/sample 
class Degenerate_peak_model(PySO.Model):
    """
    An N dimensional model which exhibits a curved degeneracy which is hard to sample or optimize
    """
    dimensions = 5
    names    = [str(i) for i in range(dimensions)]
    bounds   = [[-10,10] for i in range(dimensions)]
    periodic = [0]*dimensions

    def log_likelihood(self, param):
        x = np.array([param[p] for p in self.names])
        r = np.linalg.norm(x) 

        f = np.exp(-1/2*((r-r_star)/w)**2)+np.exp(-1/2*np.sum((x-r_star)**2))
        return(f)

# %%
mymodel = Degenerate_peak_model()

NumParticles = 1000

outdir = 'results/'

myswarm = PySO.Swarm(mymodel,
                     NumParticles,
                     Output = outdir,
                     Verbose = True,
                     Nperiodiccheckpoint = 10, # Final two args mean evolution is saved at every iteration. Only necessary if running myswarm.Plot()
                     Saveevolution = True,    ############
                     Omega = 0.964, Phip = 0.099381, Phig = 0.099381, Mh_fraction = 0.0, Maxiter=1000,
                     Velocity_minimum_factor = 100000000000,Nthreads=5)

# Clear any existing history file
history_file = os.path.join(outdir, "SwarmEvolutionHistory.dat")
if os.path.isfile(history_file): os.system('rm {}'.format(history_file))

myswarm.Run()
# Out:
# Iteration: 10, Max Value: 0.9998912726348508 at [ 0.47127085  2.16178983 -0.89599106  1.72132236 -2.73075252], Spread: 0.9998912726348508
# Iteration: 20, Max Value: 0.9999998905534175 at [-0.05135974 -2.03160341  2.48463815  1.90467109  1.43701371], Spread: 0.9999769217218702
# Iteration: 30, Max Value: 0.9999999992909079 at [ 2.21333543  0.08030979  1.01199166  1.5488179  -2.76984366], Spread: 0.9999999992909079
# Iteration: 40, Max Value: 0.9999999992909079 at [ 2.21333543  0.08030979  1.01199166  1.5488179  -2.76984366], Spread: 0.9999992375241697
# Iteration: 50, Max Value: 0.9999999992909079 at [ 2.21333543  0.08030979  1.01199166  1.5488179  -2.76984366], Spread: 0.9999825268642848
# Iteration: 60, Max Value: 0.9999999992909079 at [ 2.21333543  0.08030979  1.01199166  1.5488179  -2.76984366], Spread: 0.9999103682129358
# Iteration: 70, Max Value: 0.9999999992909079 at [ 2.21333543  0.08030979  1.01199166  1.5488179  -2.76984366], Spread: 0.9999924161866371
# Iteration: 80, Max Value: 0.999999999975508 at [ 1.51711871  0.1354426   1.17445674  1.40294249 -3.21441532], Spread: 0.9999998524608309
# Iteration: 310, Max Value: 1.0000049033362606 at [1.76958169 1.78910714 1.82747175 1.78312488 1.77431405], Spread: 0.9939315512542972
# Iteration: 320, Max Value: 1.0000049033362606 at [1.76958169 1.78910714 1.82747175 1.78312488 1.77431405], Spread: 0.9811610011159991
# Iteration: 330, Max Value: 1.0000049075510862 at [1.76378252 1.79331511 1.81137562 1.80128463 1.7740486 ], Spread: 0.9920498056389154
# Iteration: 340, Max Value: 1.0000049075510862 at [1.76378252 1.79331511 1.81137562 1.80128463 1.7740486 ], Spread: 0.9841073595984403
# Iteration: 350, Max Value: 1.0000049075510862 at [1.76378252 1.79331511 1.81137562 1.80128463 1.7740486 ], Spread: 0.9673931988924599
# Iteration: 360, Max Value: 1.0000049075510862 at [1.76378252 1.79331511 1.81137562 1.80128463 1.7740486 ], Spread: 0.9825610129292948
# Iteration: 370, Max Value: 1.0000049088036296 at [1.77624347 1.79579028 1.81677618 1.78084744 1.77421283], Spread: 0.9760840883349287
# Iteration: 380, Max Value: 1.0000049111063152 at [1.7764786  1.78953397 1.81152017 1.79519127 1.77135428], Spread: 0.9273102215276747
# Iteration: 390, Max Value: 1.0000049111063152 at [1.7764786  1.78953397 1.81152017 1.79519127 1.77135428], Spread: 0.9605824581556931
# Iteration: 400, Max Value: 1.0000049123730956 at [1.77076655 1.79162708 1.80900303 1.78858312 1.78408478], Spread: 0.9280791837582728
# Iteration: 410, Max Value: 1.0000049123730956 at [1.77076655 1.79162708 1.80900303 1.78858312 1.78408478], Spread: 0.8883337987848432
# Iteration: 420, Max Value: 1.0000049130886723 at [1.77405646 1.78947645 1.80905123 1.78935521 1.78218482], Spread: 0.924519939872904
# Iteration: 430, Max Value: 1.000004914516669 at [1.77808778 1.788069   1.80341599 1.79130503 1.78329372], Spread: 0.9266525429455702
# Iteration: 440, Max Value: 1.0000049146539398 at [1.77761258 1.7875948  1.80359777 1.7916474  1.78374252], Spread: 0.9058560211804554
# Iteration: 450, Max Value: 1.0000049152010413 at [1.77997998 1.78710741 1.80199506 1.78899321 1.78621799], Spread: 0.9599514472529642
# Iteration: 460, Max Value: 1.0000049154551824 at [1.78104017 1.78544836 1.79921323 1.7888892  1.78962532], Spread: 0.9590015277481737
# Iteration: 470, Max Value: 1.0000049154551824 at [1.78104017 1.78544836 1.79921323 1.7888892  1.78962532], Spread: 0.9275555523669432
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 20>()
#      17 history_file = os.path.join(outdir, "SwarmEvolutionHistory.dat")
#      18 if os.path.isfile(history_file): os.system('rm {}'.format(history_file))
# ---> 20 myswarm.Run()
#
# File ~/Desktop/Balrog/PySO/PySO/MWE_Swarm.py:561, in Swarm.Run(self, segmenting)
#     557         if self.Verbose: self.PrintStatus()
#     559         if self.Resume: self.Checkpoint()
# --> 561         if self.SaveEvolution: self.SaveSwarmEvolution()
#     563 self.SaveFinalResults()
#     564 if self.SaveEvolution: self.PlotSwarmEvolution()
#
# File ~/Desktop/Balrog/PySO/PySO/MWE_Swarm.py:500, in Swarm.SaveSwarmEvolution(self)
#     498 file = open(history_file_path, "a")
#     499 file.write(string)
# --> 500 file.close()
#
# KeyboardInterrupt:
